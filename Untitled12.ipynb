# %% [markdown]
# <a href="https://colab.research.google.com/github/Schwoz17/second-practice/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
corn = 5
bread = 6

total = (3 * corn) + (5 * bread)
print(f"I spent ₦ {total} today")
# Out:
# I spent ₦ 45 today

# %%
corn = 5
bread = 7

total = (3 * corn) + (5 * bread)
print(f"I spent ₦ {total} today")
# Out:
# I spent ₦ 50 today
